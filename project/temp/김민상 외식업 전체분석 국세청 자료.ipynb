# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

# 판다스 표를 모두 보는 옵션
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)

# 데이터를 가져옴
# 1번 데이터를 열어보는셀
a = "외식산업경기전망지수_10차개정_5점척도__20211101132309"
# 엑셀로 데이터가 저장되어있고 그것을 여는 방법 
# 바탕화면에 big 폴더를 만들고 01 out 폴더를 만들어서 그 안에다 넣어둠
# 파일명이 A이다. 
df = pd.read_excel('~/Desktop/big/01 out/{}.xlsx'.format(a))# , index=False)
df

import os
 
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

createFolder('~/Desktop/img')



# 국세청 외식산업 경기전망지수

# %%
os.mkdir("~/Desktop/kimbob")  # 폴더 생성

# %%
# 인덱스 삭제해줌 열과 행을 바꾸려니까 인덱스가 필요없음을 느낌
df=df.set_index('외식업종별')
df
# Out:
#                        2018.25  2018.5  2018.75   2019  2019.25  2019.5  \
# 외식업종별
# 전체소계                     74.81   73.94    72.60  69.51    71.77   70.67
# 한식소계                     73.02   72.13    70.20  67.63    69.11   69.23
# 한식 일반 음식점업               74.10   72.45    70.52  69.60    69.08   68.11
# 한식 면요리 전문점               79.55   78.33    81.34  72.22    74.11   76.20
# 한식 육류요리 전문점              69.42   70.96    69.79  64.79    69.06   70.08
# 한식 해산물요리 전문점             71.26   69.29    63.04  60.84    64.77   64.64
# 외국 전체 소계                 80.08   75.49    74.35  72.63    74.46   75.00
# 중식 음식점업                  73.45   73.96    73.10  66.84    73.20   70.72
# 일식 음식점업                  79.91   75.45    71.13  75.87    74.51   75.25
# 서양식 음식점업                 82.93   78.80    79.61  80.38    76.47   79.37
# 기타 외국식 음식점업              96.93   75.50    75.64  73.37    74.17   77.08
# 구내식당업 소계                 82.80   84.68    80.07  77.00    81.89   78.45
# ...

# %%
# 행과 열을 변환함
df=df.transpose()
df
# Out:
# 외식업종별     전체소계   한식소계  한식 일반 음식점업  한식 면요리 전문점  한식 육류요리 전문점  한식 해산물요리 전문점  \
# 2018.25  74.81  73.02       74.10       79.55        69.42         71.26
# 2018.5   73.94  72.13       72.45       78.33        70.96         69.29
# 2018.75  72.60  70.20       70.52       81.34        69.79         63.04
# 2019     69.51  67.63       69.60       72.22        64.79         60.84
# 2019.25  71.77  69.11       69.08       74.11        69.06         64.77
# 2019.5   70.67  69.23       68.11       76.20        70.08         64.64
# 2019.75  71.47  69.52       69.97       74.14        69.15         64.75
# 2020     71.44  70.10       70.95       70.36        70.49         67.05
# 2020.25  59.76  59.33       58.96       61.28        60.12         57.43
# 2020.5   64.11  63.78       60.21       70.71        66.67         64.44
# 2020.75  61.21  61.14       59.41       65.41        64.38         57.87
# 2021     59.33  57.26       55.49       59.77        60.71         56.47
# ...

# %%
# 그래프를 한번 보려고 여러가지 해봤음
a= df['전체소계']
b= df['한식소계']
c= df['외국 전체 소계']
jung = df['중식 음식점업']
il = df['일식 음식점업']

plt.plot(a, 'r-')
plt.plot(b)
plt.plot(c)
plt.plot(jung)
plt.plot(il)
plt.legend(['전체','한식','외국', ])
plt.show()

# %%
#너무 복잡해서 잘 보기가 어려움
a=df['전체소계']
b=df['한식소계']
c=df['외국 전체 소계']
d=df['구내식당업 소계']
e=df['출장음식 소계']
f=df['간이음식점 소계']
g=df['주점 소계']
h=df['비알콜 음료소계']


plt.figure(figsize=(15,15))

plt.subplot(421)
plt.plot(a, 'r-')
plt.title('전체소계')
plt.legend(['전체소계'])

plt.subplot(422)
plt.plot(a,'r-')
plt.plot(b)
plt.title('한식소계')
plt.legend(['전체소계','한식'])

plt.subplot(423)
plt.plot(a,'r-')
plt.plot(c)
plt.title('외국 전체 소계')
plt.legend(['전체소계','외국식'])

plt.subplot(424)
plt.plot(a,'r-')
plt.plot(d)
plt.title('구내식당업성장율')
plt.legend(['전체소계','구내식당'])

plt.subplot(425)
plt.plot(a,'r-')
plt.plot(e)
plt.title('출장음식 소계')
plt.legend(['전체소계','출장음식'])

plt.subplot(426)
plt.plot(a,'r-')
plt.plot(f)
plt.title('간이음식점 소계')
plt.legend(['전체소계','간이음식'])

plt.subplot(427)
plt.plot(a,'r-')
plt.plot(g)
plt.title('주점 소계')
plt.legend(['전체소계','주점'])

plt.subplot(428)
plt.plot(a,'r-')
plt.plot(h)
plt.title('비알콜 음료소계')
plt.legend(['전체소계','비알콜'])

plt.show()

# %%
# 외식업은 2018년에 비해 전반적으로 성장율이 둔화되고 있으며
# 한식은 더욱 둔화되고 있다. 
# 외국식은 업계에 비해 전반적으로 성장율이 좋은 편이며
# 구내식당의 성장율을 폭발적이다. 
# 출장음식은 전반적을로 하락하였으나 최근 성장하는 추세이며
# 간이음식점은 시장에 성장이 높은 편이다. 
# 주점은 크게 하락하고 있으며
# 비알콜점포는 전체시장에비하여 성장하는 편이다.

# %%
plt.figure(figsize=(12,8))
# 한식을 알아보고자 합니다. 

a=df['한식소계']
b=df['한식 일반 음식점업']
c=df['한식 면요리 전문점']
d=df['한식 육류요리 전문점']
e=df['한식 해산물요리 전문점']

plt.subplot(221)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('한식 일반 음식점업')
plt.legend(['한식전체','한식일반'])

plt.subplot(222)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('한식 면요리 전문점')
plt.legend(['한식전체','한식 면요리'])
           
plt.subplot(223)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('한식 육류요리 전문점')
plt.legend(['한식전체','한식 육류'])

plt.subplot(224)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('한식 해산물요리 전문점')
plt.legend(['한식전체','한식 해물'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 한식 중에는 면요리의 성장 국수 우동관련 성장이 컸었다
# 육류요리의 성장은 최근에 폭발적으로 성장하였으나
# 2021년 5월에 급락하였다
# 해산물 요리는 전반적으로 느리게 성장하고 있다.

# %%
plt.figure(figsize=(12,8))
# 외국식을 알아보고자 합니다. 

a=df['외국 전체 소계']
b=df['중식 음식점업']
c=df['일식 음식점업']
d=df['서양식 음식점업']

plt.title('중식 음식점업')
plt.title('일식 음식점업')
plt.title('서양식 음식점업')

plt.subplot(221)
plt.plot(a, 'r-')
plt.title('외국 전체')
plt.legend(['외국 전체'])

plt.subplot(222)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('중식 음식점업')
plt.legend(['외국 전체','중식'])
           
plt.subplot(223)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('일식 음식점업')
plt.legend(['외국 전체','일식'])

plt.subplot(224)
plt.plot(a, 'r-')
plt.plot(d)
plt.legend(['외국 전체','서양식'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 결과물

# 중식은 성장과 폐점을 반복
# 일식은 폐점시 더 빠르게 폐점
# 성장시 더 빠르게 성장
# 양식은 전반적으로 성장성이 좋음

# %%
d=df['구내식당업 소계']
e=df['출장음식 소계']
f=df['간이음식점 소계']
g=df['주점 소계']
h=df['비알콜 음료소계']

# %%
plt.figure(figsize=(12,12))
# 외국식을 알아보고자 합니다. 

a= df['간이음식점 소계']
b= df['제과점업']
c= df['피자 햄버거 샌드위치 및 유사 음식점업']
d= df['치킨 전문점']
e= df['김밥 및 기타 간이 음식점업']
f= df['간이 음식 포장 판매 전문점']

plt.title('간이음식점 소계')
plt.title('제과점업')
plt.title('피자 햄버거 샌드위치 및 유사 음식점업')
plt.title('치킨 전문점')
plt.title('김밥 및 기타 간이 음식점업')
plt.title('간이 음식 포장 판매 전문점')

plt.subplot(321)
plt.plot(a, 'r-')
plt.title('간이음식점 소계')
plt.legend(['간이음식점'])

plt.subplot(322)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('제과점업')
plt.legend(['간이음식점','제과점'])
           
plt.subplot(323)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('피자 햄버거 샌드위치 및 유사 음식점업')
plt.legend(['간이음식점','피자 햄버거 유사음식'])

plt.subplot(324)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('치킨 전문점')
plt.legend(['간이음식점','치킨 전문점'])

plt.subplot(325)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('김밥 및 기타 간이 음식점업')
plt.legend(['간이음식점','김밥 및 기타 간이 음식'])

plt.subplot(326)
plt.plot(a, 'r-')
plt.plot(f)
plt.title('간이 음식 포장 판매 전문점')
plt.legend(['간이음식점','포장판매 전문'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 간이 음식점에서 제과점은 크게 상승하였다. 
# 피자 샌드위치 햄버거의 성장이 뚜렸했다
# 치킨 전문점은 집입이 용의하지 않았다
# 김밥도 진입이 용이하지 않았으며
# 포장 판매 전문점도 점포수가 평균에 비해 늘지는 않았다

# %%
plt.figure(figsize=(12,8))
# 외국식을 알아보고자 합니다. 

a= df['주점 소계']
b= df['일반 유흥 주점업']
c= df['무도 유흥 주점업']
d= df['생맥주 전문점']
e= df['기타 주점업']

plt.title('주점 소계')
plt.title('일반 유흥 주점업')
plt.title('무도 유흥 주점업')
plt.title('생맥주 전문점')
plt.title('기타 주점업')

plt.subplot(221)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('일반 유흥 주점업')
plt.legend(['주점전체', '일반 유흥 주점'])

plt.subplot(222)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('무도 유흥 주점업')
plt.legend(['주점전체','무도 유흥 주점업'])
           
plt.subplot(223)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('생맥주 전문점')
plt.legend(['주점전체','생맥주 전문'])

plt.subplot(224)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('기타 주점업')
plt.legend(['주점전체','기타주점'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 유흥주점은 성장이 둔화되었으며
# 춤을 추는 무도 유흥주점도 성장이 둔화되었다
# 생맥주 주점이 2019년에 성장했으나 최근들어 줄고있다
# 기타주점업이 주점과 비슷한 경향을 보이고 있다.

# %%
plt.figure(figsize=(12,4))
# 외국식을 알아보고자 합니다. 

a= df['비알콜 음료소계']
b= df['커피 전문점']

plt.title('비알콜 음료소계')
plt.title('커피 전문점')

plt.subplot(121)
plt.plot(a, 'r-')

plt.title('비알콜 음료소계')
plt.legend(['비알콜'])

plt.subplot(122)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('커피 전문점')
plt.legend(['비알콜','커피 전문점'])

# %%
# 커피 전문점의 성장은 전반적으로 많은 편이다.

# %%
# 1번 데이터를 열어보는셀
a = "사업장_임차현황_20211101121836"

#새로운것을 불러냄
df = pd.read_excel('~/Desktop/big/01 out/{}.xlsx'.format(a), sheet_name='a')
df

# 국세청 외식산업 경기전망지수
# Out:
#          특성별(2)                 특성별(3)                 특성별(4)      2018  \
# 0        특성별(2)                 특성별(3)                 특성별(4)  임차여부 (%)
# 1        특성별(2)                 특성별(3)                 특성별(4)         예
# 2            소계                     전체                     소계      85.5
# 3         일반음식점                 일반음식전체                     소계      79.9
# 4         일반음식점                     한식                     소계      78.8
# 5         일반음식점                     중식                     소계      78.6
# 6         일반음식점                     일식                     소계      96.6
# 7         일반음식점                    서양식                     소계      93.7
# 8         일반음식점                 기타 외국식                     소계      94.9
# 9       일반음식점 외              일반음식점외 전체                     소계      91.6
# 10      일반음식점 외               기관 구내식당업                     소계      59.1
# 11      일반음식점 외              출장·이동음식점업                     소계      73.6
# ...

# %%
# 1번 임차 여부 알아보기
# 데이터를 쪼개오기
df1 = df.iloc[2:9,[1,3,5,7]]
df1
# Out:
#    특성별(3)  2018  2019  2020
# 2      전체  85.5  89.9  85.6
# 3  일반음식전체  79.9  87.9  80.8
# 4      한식  78.8  88.2  79.9
# 5      중식  78.6  78.4    78
# 6      일식  96.6    91  93.1
# 7     서양식  93.7  93.9  91.1
# 8  기타 외국식  94.9  94.4  88.4

# %%
# 인덱스 버리기
# 인덱스 삭제
df1=df1.set_index('특성별(3)')
df1
# Out:
#         2018  2019  2020
# 특성별(3)
# 전체      85.5  89.9  85.6
# 일반음식전체  79.9  87.9  80.8
# 한식      78.8  88.2  79.9
# 중식      78.6  78.4    78
# 일식      96.6    91  93.1
# 서양식     93.7  93.9  91.1
# 기타 외국식  94.9  94.4  88.4

# %%
# 행열 뒤집기
df1=df1.transpose()
df1
# Out:
# 특성별(3)    전체 일반음식전체    한식    중식    일식   서양식 기타 외국식
# 2018    85.5   79.9  78.8  78.6  96.6  93.7   94.9
# 2019    89.9   87.9  88.2  78.4    91  93.9   94.4
# 2020    85.6   80.8  79.9    78  93.1  91.1   88.4

# %%
# 그래프로  임대한것 임대비율 알아보기

plt.figure(figsize=(15,15))

a= df1['전체']
b= df1['일반음식전체']
c= df1['한식']
d= df1['중식']
e= df1['일식']
f= df1['서양식']
g= df1['기타 외국식']

plt.title('전체 임차비율')
plt.title('일반음식전체 임차비율')
plt.title('한식 임차비율')
plt.title('중식 임차비율')
plt.title('일식 임차비율')
plt.title('서양식 임차비율')
plt.title('기타 외국식 임차비율')

plt.subplot(321)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('일반음식전체 임차비율')
plt.legend(['전체','일반음식점'])

plt.subplot(322)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('한식 임차비율')
plt.legend(['전체','한식 임차비율'])

plt.subplot(323)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('중식 임차비율')
plt.legend(['전체','중식 임차비율'])

plt.subplot(324)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('일식 임차비율')
plt.legend(['전체','일식 임차비율'])

plt.subplot(325)
plt.plot(a, 'r-')
plt.plot(f)
plt.title('서양식 임차비율')
plt.legend(['전체','서양식 임차비율'])

plt.subplot(326)
plt.plot(a, 'r-')
plt.plot(g)
plt.title('기타 외국식 임차비율')
plt.legend(['전체','기타 외국식 임차비율'])

plt.show()

# %%
# 일반음식점과 일반음식점이 아닌 종류로 분류된다. 
# 일반음식점은 자기 건물이 아니라 임차해서 보통 비지니스를한다
# 1. 한식과 일반음식은 2019년 임대를 많이 하고 그 이후에 평균비율에 비해
# 자가를 통해서 운영하는 경우가 많은것 같다. 
# 2. 중식은 일반 음식점에 비해 월세를 내고 하는 비율이 적은 편이다. 운영이 훨씬 안정적이라고 
# 볼수 있다. 
# 3. 일식은 2018년에 개업을 많이 한 것으로 보이며, 2020년 이후에도 개업을 많이 한 것으로 보인다
# 대부분 일식은 90%이상이 월세를 내고 운영하는 편이다. 

# 4. 서양식도 일식과 마찬가지로 임대하여 사용하는 비율이 높고 2018년에는 개업을 많이 하였으나
# 성장율이 높지는 않은 것으로 보인다. 
# 5. 기타외국식은 현 데이터에서 분류가 나와있지는 않으나. 임대에서 점차 자가로 가는 것이 보인다.

# %%
# 일반음식점외에 어떤 비율인지 알아보고 싶다. 
df[:10]
# Out:
#     특성별(2)     특성별(3)  특성별(4)      2018    2018.1      2019    2019.1  \
# 0   특성별(2)     특성별(3)  특성별(4)  임차여부 (%)  임차여부 (%)  임차여부 (%)  임차여부 (%)
# 1   특성별(2)     특성별(3)  특성별(4)         예       아니오         예       아니오
# 2       소계         전체      소계      85.5      14.5      89.9      10.1
# 3    일반음식점     일반음식전체      소계      79.9      20.1      87.9      12.1
# 4    일반음식점         한식      소계      78.8      21.2      88.2      11.8
# 5    일반음식점         중식      소계      78.6      21.4      78.4      21.6
# 6    일반음식점         일식      소계      96.6       3.4        91         9
# 7    일반음식점        서양식      소계      93.7       6.3      93.9       6.1
# 8    일반음식점     기타 외국식      소계      94.9       5.1      94.4       5.6
# 9  일반음식점 외  일반음식점외 전체      소계      91.6       8.4        92         8
#
#        2020    2020.1
# 0  임차여부 (%)  임차여부 (%)
# 1         예       아니오
# 2      85.6      14.4
# 3      80.8      19.2
# 4      79.9      20.1
# 5        78        22
# 6      93.1       6.9
# ...

# %%
# 1번 임차 여부 알아보기
# 데이터를 쪼개오기
df2 = df.iloc[9:18,[1,3,5,7]]
df2
# Out:
#                    특성별(3)  2018  2019  2020
# 9               일반음식점외 전체  91.6    92  90.9
# 10               기관 구내식당업  59.1    70  59.2
# 11              출장·이동음식점업  73.6  75.9  78.2
# 12                    제과점  92.6  93.7  92.2
# 13  피자·햄버거·샌드위치 및 유사 음식점업  94.3  95.9  94.6
# 14                  치킨전문점    92  94.4  89.3
# 15        김밥 및 기타 간이 음식점업  88.1  89.2  90.2
# 16        간이 음식 포장 판매 전문점  79.2  91.4  85.9
# 17                    주점업  95.9  93.9  94.6

# %%
# 인덱스 짜르고 뒤집기
# 인덱스 버리기
# 인덱스 삭제
df2=df2.set_index('특성별(3)')

# 뒤집기
df2=df2.transpose()
df2
# Out:
# 특성별(3) 일반음식점외 전체 기관 구내식당업 출장·이동음식점업   제과점 피자·햄버거·샌드위치 및 유사 음식점업 치킨전문점  \
# 2018        91.6     59.1      73.6  92.6                  94.3    92
# 2019          92       70      75.9  93.7                  95.9  94.4
# 2020        90.9     59.2      78.2  92.2                  94.6  89.3
#
# 특성별(3) 김밥 및 기타 간이 음식점업 간이 음식 포장 판매 전문점   주점업
# 2018              88.1            79.2  95.9
# 2019              89.2            91.4  93.9
# 2020              90.2            85.9  94.6

# %%
plt.figure(figsize=(15,15))
# 일반음식점이 아닌곳은 어떤가?

a= df2['일반음식점외 전체']
b= df2['기관 구내식당업']
c= df2['출장·이동음식점업']
d= df2['제과점']
e= df2['피자·햄버거·샌드위치 및 유사 음식점업']
f= df2['치킨전문점']
g= df2['김밥 및 기타 간이 음식점업']
h= df2['간이 음식 포장 판매 전문점']
i= df2['주점업']

plt.title('일반음식점외 전체')
plt.title('기관 구내식당업')
plt.title('출장·이동음식점업')
plt.title('제과점')
plt.title('피자·햄버거·샌드위치 및 유사 음식점업')
plt.title('치킨전문점')
plt.title('김밥 및 기타 간이 음식점업')
plt.title('간이 음식 포장 판매 전문점')
plt.title('주점업')

plt.subplot(421)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('기관 구내식당업')
plt.legend(['일반음식점외','기관 구내식당업'])

plt.subplot(422)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('출장·이동음식점업')
plt.legend(['일반음식점외','출장/이동'])


plt.subplot(423)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('제과점')
plt.legend(['일반음식점외','제과점'])


plt.subplot(424)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('피자·햄버거·샌드위치')
plt.legend(['일반음식점외','피자 햄버거'])


plt.subplot(425)
plt.plot(a, 'r-')
plt.plot(f)
plt.title('치킨전문점')
plt.legend(['일반음식점외','치킨 전문점'])


plt.subplot(426)
plt.plot(a, 'r-')
plt.plot(g)
plt.title('김밥 및 간이 음식점업')
plt.legend(['일반음식점외','김밥 간이음식'])


plt.subplot(427)
plt.plot(a, 'r-')
plt.plot(h)
plt.title('음식 포장 판매 전문점')
plt.legend(['일반음식점외','포장판매'])


plt.subplot(428)
plt.plot(a, 'r-')
plt.plot(i)
plt.title('주점업')
plt.legend(['일반음식점외','주점'])

plt.show()

# %%
# # 이번에는 일반음식점이 아닌 기타 음식을 다루는 업종은 어떤지 알아보고자 하였다. 
# 기관구내 식당업은 굉장히 특이한 자료를 보여주었다. 60프로정도가 임대를 하였고
# 나머지 40%가량의 자가였다. 공장이나 기관내에 식당업을 하여 직원들의 식사를 공급하는 
# 비율이 많은 것으로 보인다. 이 자료는 위의 자료를 보며 성장율을 확인해보는것이 좋겠다고 생각한다. 

# 2. 출장이동 음식점도 자가가 많은 편이며, 점차 임대비율이 상승하는 것으로 보인다. 
# 3. 제과점은 임대비율이 높으며, 2019년에 많은 사람들이 개업을 한것으로 보인다. 
# 4. 피자 햄버거 샌드위치는 대부분 임대를 통해 수익을 낸다. 
# 고수익이 가능한 점포는 임대를 하는것이 좋은것 같다. 
# 5. 치킨 전문점은 임대를 많이 하였으나. 2020년 이후에 자가확율이 높아진것을 볼 수 있다. 
# 돈을 벌어서 산것인지, 임대업자가 폐업을 한것인지는 확인할 수는 없다. 
# 6. 김밥 간이 음식점은 자가 비율이 약간 높은 편이나 점차 성장해 나가는 것 같다. 
# 7. 음식포장 판매전문점은 2019년에 빠르게 성장했으나. 2020년에 성장이 줄어든것 같다
# 8. 주점업은 임대비율이 높은 편이다. 주점은 자가로 하는 비율이 높지 않은것으로 보인다.

# %%
# 지역별로 차이가 있는지
# 1번 임차 여부 알아보기
# 데이터를 쪼개오기
df3 = df.iloc[21:27,[0,3,5,7]]
df3
# Out:
#    특성별(2)  2018  2019  2020
# 21    서울권  98.7  96.1  95.5
# 22    수도권  97.5  94.9  93.1
# 23    충청권  82.1  84.1  76.7
# 24    호남권  58.2  83.7  75.5
# 25    경남권  83.4  90.6  79.8
# 26    경북권  75.9  79.6  79.5

# %%
# 인덱스 짜르고 뒤집기
# 인덱스 버리기
# 인덱스 삭제
df3=df3.set_index('특성별(2)')

# 뒤집기
df3=df3.transpose()
df3
# Out:
# 특성별(2)   서울권   수도권   충청권   호남권   경남권   경북권
# 2018    98.7  97.5  82.1  58.2  83.4  75.9
# 2019    96.1  94.9  84.1  83.7  90.6  79.6
# 2020    95.5  93.1  76.7  75.5  79.8  79.5

# %%
plt.figure(figsize=(15,15))

a= df1['전체']
b=df3['서울권']
c=df3['수도권']
d=df3['충청권']
e=df3['호남권']
f=df3['경남권']
g=df3['경북권']

plt.title('서울권')
plt.title('수도권')
plt.title('충청권')
plt.title('호남권')
plt.title('경남권')
plt.title('경북권')

plt.subplot(321)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('서울권')
plt.legend(['전체','서울'])

plt.subplot(322)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('경기 수도권')
plt.legend(['전체','경기 수도권'])

plt.subplot(323)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('충청권')
plt.legend(['전체','충남/충북'])

plt.subplot(324)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('호남권')
plt.legend(['전체','호남'])

plt.subplot(325)
plt.plot(a, 'r-')
plt.plot(f)
plt.title('경남권')
plt.legend(['전체','경남'])

plt.subplot(326)
plt.plot(a, 'r-')
plt.plot(g)
plt.title('경북권')
plt.legend(['전체','경북'])

plt.show()

# %%
# 1. 서울은 임대하여 음식업을 하는 사람들이 많고
# 2. 경기도는 임대에서 자가로 비율이 높아지고 있다. 
# 3. 충청권은 자가 비율이 높아지고 있다. 사업이 안정적이라는 것을 표현한다고 본다
# 4. 호남은 자가비율이 매우 높았으나 점차 임대비율도 높아지는것으로 보인다
# 5. 경남권은 2019년 빠르게 성장했으나. 2020년 임대비율이 엄청난 하락을 보였다. 
# 6. 경북권은 안정적인 그래프를 보여주고 있다고 생각된다.

# %%
# 투자금액별로 자가비율이 높은지 낮은지 알아 보고자 한다. /
# 1번 임차 여부 알아보기
# 데이터를 쪼개오기
df4 = df.iloc[27:,[0,3,5,7]]
df4
# Out:
#          특성별(2)  2018  2019  2020
# 27      5천만원 미만  78.4  83.9  74.9
# 28  5천만원~1억원 미만  80.4  86.5    84
# 29   1억원~5억원 미만  89.7    92  88.6
# 30       5억원 이상  77.5  86.4  82.4

# %%
# 인덱스 짜르고 뒤집기
# 인덱스 버리기
# 인덱스 삭제
df4=df4.set_index('특성별(2)')

# 뒤집기
df4=df4.transpose()
df4
# Out:
# 특성별(2) 5천만원 미만 5천만원~1억원 미만 1억원~5억원 미만 5억원 이상
# 2018      78.4        80.4       89.7   77.5
# 2019      83.9        86.5         92   86.4
# 2020      74.9          84       88.6   82.4

# %%
df4['평균']= (df4['5천만원 미만'] +df4['5천만원~1억원 미만'] +df4['1억원~5억원 미만']+df4['5억원 이상'] )/4
df4
# Out:
# 특성별(2) 5천만원 미만 5천만원~1억원 미만 1억원~5억원 미만 5억원 이상      평균
# 2018      78.4        80.4       89.7   77.5    81.5
# 2019      83.9        86.5         92   86.4    87.2
# 2020      74.9          84       88.6   82.4  82.475

# %%
plt.figure(figsize=(12,8))
# 외국식을 알아보고자 합니다. 

b=df4['5천만원 미만']
c=df4['5천만원~1억원 미만']
d=df4['1억원~5억원 미만']
e=df4['5억원 이상']
a=df4['평균']


plt.title('5천만원 미만')
plt.title('5천만원~1억원 미만')
plt.title('1억원~5억원 미만')
plt.title('5억원 이상')
plt.title('평균')

plt.subplot(221)
plt.plot(a, 'r-')
plt.plot(b)
plt.title('5천만원 미만')
plt.legend(['전체평균', '5천만원 미만'])

plt.subplot(222)
plt.plot(a, 'r-')
plt.plot(c)
plt.title('5천만원~1억원 미만')
plt.legend(['전체평균', '5천~1억원'])

plt.subplot(223)
plt.plot(a, 'r-')
plt.plot(d)
plt.title('1억원~5억원 미만')
plt.legend(['전체평균', '1억~5억 미만'])

plt.subplot(224)
plt.plot(a, 'r-')
plt.plot(e)
plt.title('5억원 이상')
plt.legend(['전체평균', '5억이상'])

plt.show()

# %%
# 1. 5천만원 이하 투자자는 자가로 하려는 경향이 높고
# 2. 1억 이하 투자자는 자가비율에서 월세비중이 높아지고 있다
# 3. 5억이하 투자자는 대부분 월세로 창업을 시작하며
# 4. 5억이상 투자자는 자가비율이 많았으나 월세비율노 높아지고 있다.

# %%
# 1번 데이터를 열어보는셀
a = "사업장_임차현황_20211101121836"
dfb = pd.read_excel('~/Desktop/big/01 out/{}.xlsx'.format(a), sheet_name='b')
dfb

# 국세청 외식산업 경기전망지수
# Out:
#     특성별(1)       특성별(2)                 특성별(3)                 특성별(4)  \
# 0   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 1   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 2       전체           소계                     전체                     소계
# 3      업종별        일반음식점                일반음식점전체                     소계
# 4      업종별        일반음식점                     한식                     소계
# 5      업종별        일반음식점                     중식                     소계
# 6      업종별        일반음식점                     일식                     소계
# 7      업종별        일반음식점                    서양식                     소계
# 8      업종별        일반음식점                 기타 외국식                     소계
# 9      업종별      일반음식점 외              일반음식점외 소계                     소계
# 10     업종별      일반음식점 외               기관 구내식당업                     소계
# 11     업종별      일반음식점 외              출장·이동음식점업                     소계
# ...

# %%
# 투자금액별로 자가비율이 높은지 낮은지 알아 보고자 한다. /
# 1번 임차 여부 알아보기
# 데이터를 쪼개오기
dfb1 = dfb.iloc[:,:]
dfb1
# 1천만원 미만 (%)	1천만원~2천만원 미만 (%)	2천만원~5천만원 미만 (%)	5천만원~1억 미만 (%)	1억 이상 (%)	무응답 (%)
#
# Out:
#     특성별(1)       특성별(2)                 특성별(3)                 특성별(4)  \
# 0   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 1   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 2       전체           소계                     전체                     소계
# 3      업종별        일반음식점                일반음식점전체                     소계
# 4      업종별        일반음식점                     한식                     소계
# 5      업종별        일반음식점                     중식                     소계
# 6      업종별        일반음식점                     일식                     소계
# 7      업종별        일반음식점                    서양식                     소계
# 8      업종별        일반음식점                 기타 외국식                     소계
# 9      업종별      일반음식점 외              일반음식점외 소계                     소계
# 10     업종별      일반음식점 외               기관 구내식당업                     소계
# 11     업종별      일반음식점 외              출장·이동음식점업                     소계
# ...

# %%
kk18= dfb1.iloc[2:3,4:10]
# 세로로 바꿔줌
# 뒤집기
kk18=kk18.transpose()
kk18=kk18[2]
kk18
# Out:
# 2018       8.7
# 2018.1    15.9
# 2018.2    46.7
# 2018.3    20.8
# 2018.4       4
# 2018.5     3.9
# Name: 2, dtype: object

# %%
kk19= dfb1.iloc[2:3,11:17]
# 세로로 바꿔줌
# 뒤집기
kk19=kk19.transpose()
kk19=kk19[2]
kk19
# Out:
# 2019       5.9
# 2019.1    22.8
# 2019.2    47.1
# 2019.3    19.3
# 2019.4     2.1
# 2019.5     2.7
# Name: 2, dtype: object

# %%
kk20= dfb1.iloc[2:3,18:24]
# 세로로 바꿔줌
# 뒤집기
kk20=kk20.transpose()
kk20=kk20[2]
kk20
# Out:
# 2020       6.9
# 2020.1    19.1
# 2020.2    48.5
# 2020.3    20.6
# 2020.4       5
# 2019.7       0
# Name: 2, dtype: object

# %%
import matplotlib.pyplot as plt

list = [kk18, kk19, kk20]
title = ['2018', '2019', '2020']

for i ,t in zip(list,title):
    t= t+' 년도 전체 퍼센트'
    plt.figure(figsize=(5,5))
    title_font = {    'fontsize': 26, 'fontweight': 'bold'}
    plt.title(t,fontdict=title_font)
    
    labels = ['1천 미만','2천 미만','5천 미만','1억 미만','1억 이상','무응답' ]

    plt.pie(i, labels=labels,autopct='%.1f%%',startangle=90)
    plt.show()

# %%
kk18= dfb.iloc[4:5,4:10]
kk18=kk18.transpose()
kk18=kk18[4]

kk19= dfb.iloc[4:5,11:17]
# 세로로 바꿔줌
# 뒤집기
kk19=kk19.transpose()
kk19=kk19[4]

kk20= dfb.iloc[4:5,18:24]
# 세로로 바꿔줌
# 뒤집기
kk20=kk20.transpose()
kk20=kk20[4]


list = [kk18, kk19, kk20]
title = ['2018', '2019', '2020']

for i ,t in zip(list,title):
    t= t+' 년도 한식 창업 금액'
    plt.figure(figsize=(5,5))
    title_font = {    'fontsize': 26, 'fontweight': 'bold'}
    plt.title(t,fontdict=title_font)
    
    labels = ['1천 미만','2천 미만','5천 미만','1억 미만','1억 이상','무응답' ]

    plt.pie(i, labels=labels,autopct='%.1f%%',startangle=90)
    plt.show()

# %%
# 중식
kk18= dfb.iloc[5:6,4:10]
kk18=kk18.transpose()
kk18=kk18[5]

kk19= dfb.iloc[5:6,11:17]
# 세로로 바꿔줌
# 뒤집기
kk19=kk19.transpose()
kk19=kk19[5]

kk20= dfb.iloc[5:6,18:24]
# 세로로 바꿔줌
# 뒤집기
kk20=kk20.transpose()
kk20=kk20[5]


list = [kk18, kk19, kk20]
title = ['2018', '2019', '2020']

for i ,t in zip(list,title):
    t= t+' 년도 중식 창업 금액'
    plt.figure(figsize=(5,5))
    title_font = {    'fontsize': 26, 'fontweight': 'bold'}
    plt.title(t,fontdict=title_font)
    
    labels = ['1천 미만','2천 미만','5천 미만','1억 미만','1억 이상','무응답' ]

    plt.pie(i, labels=labels,autopct='%.1f%%',startangle=90)
    plt.show()

# %%
# 2 = 일반음식점전체  ，3 = 한식    ，4 = 중식    ，5 = 일식    ，
# 6 = 서양식  ，7 = 기타 외국식 ，8 = 일반음식점외 소계   ，9 = 기관 구내식당업 ，
# 10 = 출장·이동음식점업   ，11 = 제과점  ，
# 12 = 피자·햄버거·샌드위치 및 유사 음식점업   ，13 = 치킨전문점  ，
# 14 = 김밥 및 기타 간이 음식점업  ，15 = 간이 음식 포장 판매 전문점  ，16 = 주점업  ，
# 17 = 비알콜 음료점업 ，


# 18 = 프랜차이즈  ，19 = 비프랜차이즈    ，

# 20 = 서울권  ，
# 21 = 수도권  ，22 = 충청권  ，23 = 호남권  ，24 = 경남권  ，25 = 경북권  ，
# 26 = 5천만원 미만    ，27 = 5천만원~1억원 미만  ，28 = 1억원~5억원 미만    ，
# 29 = 5억원 이상

# %%
# 작업하다보니 할만한 방법이 생김

a= 20

name = dfb.iloc[a+1,2]
print(name)

kk18= dfb.iloc[a+1:a+2,4:10]
kk18=kk18.transpose()
kk18=kk18[a+1]
# print(kk18)


kk19= dfb.iloc[a+1:a+2,11:17]
# 세로로 바꿔줌
# 뒤집기
kk19=kk19.transpose()
kk19=kk19[a+1]
# print(kk19)

kk20= dfb.iloc[a+1:a+2,18:24]
# 세로로 바꿔줌
# 뒤집기
kk20=kk20.transpose()
kk20=kk20[a+1]
# print(kk20)


list = [kk18, kk19, kk20]
title = ['2018', '2019', '2020']

for i ,t in zip(list,title):
    t= t+' 년도 {} 창업 금액'.format(name)
    
    plt.figure(figsize=(5,5))
    
    title_font = {'fontsize': 12, 'fontweight': 'bold'}
    plt.title(t, fontdict=title_font)
    
    labels = ['1천 미만','2천 미만','5천 미만','1억 미만','1억 이상','무응답' ]

    plt.pie(i, labels=labels,autopct='%.1f%%',startangle=90)
    plt.savefig('savefig_default.png')
    
    plt.show()
# Out:
# 서울권

# %%
# dfb

a= 5

dfb.iloc[a+1,2]
# Out:
# '일식'

# %%
dfb
# Out:
#     특성별(1)       특성별(2)                 특성별(3)                 특성별(4)  \
# 0   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 1   특성별(1)       특성별(2)                 특성별(3)                 특성별(4)
# 2       전체           소계                     전체                     소계
# 3      업종별        일반음식점                일반음식점전체                     소계
# 4      업종별        일반음식점                     한식                     소계
# 5      업종별        일반음식점                     중식                     소계
# 6      업종별        일반음식점                     일식                     소계
# 7      업종별        일반음식점                    서양식                     소계
# 8      업종별        일반음식점                 기타 외국식                     소계
# 9      업종별      일반음식점 외              일반음식점외 소계                     소계
# 10     업종별      일반음식점 외               기관 구내식당업                     소계
# 11     업종별      일반음식점 외              출장·이동음식점업                     소계
# ...

# %%
a= 3

name = dfb.iloc[a+1,2]
print(name)

kk18= dfb.iloc[a+1:a+2,4:10]
kk18=kk18.transpose()
kk18=kk18[a+1]
# print(kk18)


kk19= dfb.iloc[a+1:a+2,11:17]
# 세로로 바꿔줌
# 뒤집기
kk19=kk19.transpose()
kk19=kk19[a+1]
# print(kk19)

kk20= dfb.iloc[a+1:a+2,18:24]
# 세로로 바꿔줌
# 뒤집기
kk20=kk20.transpose()
kk20=kk20[a+1]
# print(kk20)


list = [kk18, kk19, kk20]
title = ['2018', '2019', '2020']

for i ,t in zip(list,title):
    t= t+' 년도 {} 창업 금액'.format(name)
    
    plt.figure(figsize=(5,5))
    
    title_font = {'fontsize': 12, 'fontweight': 'bold'}
    plt.title(t, fontdict=title_font)
    
    labels = ['1천 미만','2천 미만','5천 미만','1억 미만','1억 이상','무응답' ]

    plt.pie(i, labels=labels,autopct='%.1f%%',startangle=90)
    
    plt.show()
# Out:
# 한식
